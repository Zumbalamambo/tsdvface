# %%
import os
# %matplotlib inline


# os.system('python src/train_tripletloss.py --logs_base_dir logs/ --models_base_dir my_models/ \
#           --pretrained_model /home/hungnv/master/src/Face_Recognition-master/lib/src/ckpt/20180402-114759/model-20180402-114759.ckpt-275 \
#           --data_dir datasets/celebrity_1000_mtcnnpy_182 --lfw_dir datasets/lfw_mtcnnpy_160 --max_nrof_epochs 1 \
#           --embedding_size 128')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-2727a6db12de> in <module>()
#       3
#       4
# ----> 5 os.system('python src/train_tripletloss.py --logs_base_dir logs/ --models_base_dir my_models/           --pretrained_model /home/hungnv/master/src/Face_Recognition-master/lib/src/ckpt/20180402-114759/model-20180402-114759.ckpt-275           --data_dir datasets/celebrity_1000_mtcnnpy_182 --lfw_dir datasets/lfw_mtcnnpy_160 --max_nrof_epochs 1           --embedding_size 128').read
#
# AttributeError: 'int' object has no attribute 'read'

# %%
import os

# %%
path = '\\10.116.16.22\public1\TSDV photos\[Photo] Year end party\NamNB'

for root, dirs, files in os.walk('/home/hungnv/master/src/facenet/data/celebrity_1000/3/'):
    print files
# Out:
# ['2262288362,1364311562_align.jpg', '135890604,3877792984_align.jpg', '1092394768,3945685320_align.jpg', '1532553887,3641222690_align.jpg', '2450802564,1646452478_align.jpg', '1787205978,2173708016_align.jpg', '1058473676,592104524_align.jpg', '1318820221,3722388711_align.jpg', '338674853,450465095_align.jpg', '1840880367,2364006447_align.jpg', '1112313817,4246019570_align.jpg', '1225741000,1276459878_align.jpg', '3758690567,1155902686_align.jpg', '3803737931,2386243536_align.jpg', '379436666,2828041204_align.jpg', '3279620444,4108698154_align.jpg', '643750256,3273309011_align.jpg', '2155291610,2991077263_align.jpg', '62668801,4069859626_align.jpg', '799255852,2153388234_align.jpg', '1082416889,2167024586_align.jpg', '179160409,2553756078_align.jpg', '1319091515,1909999991_align.jpg', '3814705291,3235986741_align.jpg', '1419695577,3524583929_align.jpg', '3904310980,3069861687_align.jpg', '163941997,3825774515_align.jpg', '3421528371,3419478291_align.jpg', '2255046386,2916699418_align
# ...
